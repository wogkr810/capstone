# %%
params=['#f25858','#f68cde','#c472ec','#7d5eff','#5770ef','#3142b2','#7bb6eb','#92ecff','#83f3bb','#aff696','#e4ffb5','#fce96d','#ffec71','#b9a09c','#a1a1a1']

f, axes = plt.subplots(1, len(params), sharex=True, sharey=True)
f.set_size_inches((16, 4)) 
for i in range(0, len(params)):
    axes[i].plot(x, y, color=params[i])
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

params=['#f25858','#f68cde','#c472ec','#7d5eff','#5770ef','#3142b2','#7bb6eb','#92ecff','#83f3bb','#aff696','#e4ffb5','#fce96d','#ffec71','#b9a09c','#a1a1a1']
colors = params
yuri_cmap=ListedColormap(colors)

# %%
X = np.random.normal(0, 1, 100)
Y = np.random.normal(0, 1, 100)
C = np.random.randint(0, 5, 100)

f, axes = plt.subplots(1, 4, sharex=True, sharey=True)
f.set_size_inches((16, 4)) 
for i in range(0, 4):
    axes[i].scatter(X, Y, c=C, cmap=cmap)
plt.show()

# %%
import random
import matplotlib.pyplot as plt

s_x = random.sample(range(0,100),20)
s_y = random.sample(range(0,100),20)

s = plt.scatter(s_x,s_y,c = s_x, cmap=cmap)

c = plt.colorbar()
